# %%
import importlib
import my_mod as a
importlib.reload(a)

print(dir(a))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'nd_list', 'nd_set', 'nd_tuple', 'nl', 'nlp']

# %%
my_list = [1,2,3,4,[5,6]]

a.nd_list(my_list)
print("break")
a.nd_tuple((1,2,3,(4,5)))
print("break")
a.nd_set({1,2,3,{5,6}})
# Out:
# 1
# 2
# 3
# 4
# 	5
# 	6
# break
# 1
# 2
# 3
# 	4
# 	5
# break
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 7
#       5 a.nd_tuple((1,2,3,(4,5)))
#       6 print("break")
# ----> 7 a.nd_set({1,2,3,{5,6}})
#
# TypeError: unhashable type: 'set'
